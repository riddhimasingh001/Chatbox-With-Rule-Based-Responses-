# %%
import random
import re
from datetime import datetime

memory = {
    "name": None,
    "mood": None
}

def get_weather():
    return "I can't fetch real-time weather yet, but I hope it's nice where you are! ☀️"

def get_math_answer(expression):
    try:
        result = eval(expression)
        return f"That equals {result}"
    except:
        return "Hmm, I couldn't calculate that. Try a simpler math expression."

def chatbot():
    print("Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.")

    jokes = [
        "Why don’t scientists trust atoms? Because they make up everything!",
        "Why did the math book look sad? Because it had too many problems.",
        "I'm reading a book on anti-gravity. It's impossible to put down!"
    ]

    facts = [
        "Sloths can hold their breath longer than dolphins.",
        "Octopuses have three hearts and blue blood.",
        "Bananas are berries, but strawberries aren’t."
    ]

    advice_list = [
        "Stay positive and keep moving forward!",
        "Take regular breaks while studying or working.",
        "Keep a gratitude journal—it really helps with mental clarity."
    ]

    songs = [
        "'Blinding Lights' by The Weeknd",
        "'Levitating' by Dua Lipa",
        "'Perfect' by Ed Sheeran",
        "'Shape of You' by Ed Sheeran"
    ]

    movies = [
        "Inception (2010) - Sci-Fi",
        "The Shawshank Redemption (1994) - Drama",
        "Interstellar (2014) - Sci-Fi",
        "Inside Out (2015) - Animation"
    ]

    fallback_responses = [
        "That's an interesting point. Could you explain a bit more?",
        "I'd love to know more about what you're thinking!",
        "Can you tell me a little more about that?",
        "That sounds important—go on, I'm listening."
    ]

    while True:
        user_input = input("You: ").lower().strip()

        if user_input in ["exit", "bye", "goodbye", "quit"]:
            name = memory['name'] or 'friend'
            print(f"Chatbot: Goodbye {name}! Take care and talk soon 💛")
            break

        if "my name is" in user_input:
            name_match = re.search(r"my name is (\w+)", user_input)
            if name_match:
                memory['name'] = name_match.group(1).capitalize()
                print(f"Chatbot: Great to meet you, {memory['name']}! 😊")
            continue

        if "i feel" in user_input:
            mood_match = re.search(r"i feel (\w+)", user_input)
            if mood_match:
                memory['mood'] = mood_match.group(1)
                print(f"Chatbot: Got it — you're feeling {memory['mood']}. Want to talk about it?")
            continue

        if re.search(r"\b(hi|hello|hey|yo|sup)\b", user_input):
            greeting = f"Hey {memory['name']}!" if memory['name'] else "Hey there!"
            print(f"Chatbot: {greeting} How can I brighten your day today?")
            continue

        if "how are you" in user_input:
            print("Chatbot: I’m all good! What about you? 😊")
            continue

        if re.search(r"\b(thanks|thank you|thx|ty|ok thanks|okay thanks|oh thanks|ohh thanks)\b", user_input):
            print("Chatbot: You're very welcome! 💛")
            continue

        if re.search(r"\b(nice|cool|great|awesome|sweet|amazing|lovely)\b", user_input):
            print("Chatbot: Glad you think so! 😄")
            continue

        if re.search(r"\b(yes|yeah|yup|sure|of course|yess)\b", user_input):
            print("Chatbot: Awesome! Let’s go on ✨")
            continue

        if re.search(r"\b(no|nope|nah|not really|never mind)\b", user_input):
            print("Chatbot: No worries, we can switch it up! 😊")
            continue

        if "weather" in user_input:
            print("Chatbot:", get_weather())
            continue

        if re.search(r"\b(date|day|today)\b", user_input):
            print("Chatbot: Today is", datetime.today().strftime("%A, %B %d, %Y"))
            continue

        if "time" in user_input:
            print("Chatbot: It’s", datetime.now().strftime("%I:%M %p"))
            continue

        if re.search(r"\b(joke|funny|laugh)\b", user_input):
            print("Chatbot:", random.choice(jokes))
            continue

        if re.search(r"\b(fact|did you know|interesting)\b", user_input):
            print("Chatbot:", random.choice(facts))
            continue

        if re.search(r"\b(advice|tip|suggestion)\b", user_input):
            print("Chatbot:", random.choice(advice_list))
            continue

        if re.search(r"\b(song|music|listen|track)\b", user_input):
            print("Chatbot: How about listening to", random.choice(songs))
            continue

        if re.search(r"\b(movie|film|watch|cinema)\b", user_input):
            print("Chatbot: You might like:", random.choice(movies))
            continue

        if re.search(r"\d+[\+\-\*/]\d+", user_input):
            print("Chatbot:", get_math_answer(user_input))
            continue

        print("Chatbot:", random.choice(fallback_responses))

chatbot()
# Out:
# Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.
# Chatbot: Hey there! How can I brighten your day today?
# Chatbot: You might like: Interstellar (2014) - Sci-Fi
# Chatbot: Awesome! Let’s go on ✨
# Chatbot: You're very welcome! 💛
# Chatbot: I'd love to know more about what you're thinking!
# Chatbot: You're very welcome! 💛
# Chatbot: I'd love to know more about what you're thinking!
# Chatbot: No worries, we can switch it up! 😊
# Chatbot: Awesome! Let’s go on ✨
# Chatbot: Can you tell me a little more about that?
# Chatbot: Can you tell me a little more about that?
# Chatbot: No worries, we can switch it up! 😊
# Chatbot: How about listening to 'Shape of You' by Ed Sheeran
# Chatbot: Glad you think so! 😄
# Chatbot: I’m all good! What about you? 😊
# Chatbot: I'd love to know more about what you're thinking!
# Chatbot: I'd love to know more about what you're thinking!
# Chatbot: That sounds important—go on, I'm listening.
# ...

# %%
import random
import re
from datetime import datetime

memory = {
    "name": None,
    "mood": None
}

def get_weather():
    return "I can't fetch real-time weather yet, but I hope it's nice where you are! ☀️"

def get_math_answer(expression):
    try:
        result = eval(expression)
        return f"That equals {result}"
    except:
        return "Hmm, I couldn't calculate that. Try a simpler math expression."

def chatbot():
    print("Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.")

    jokes = [
        "Why don’t scientists trust atoms? Because they make up everything!",
        "Why did the math book look sad? Because it had too many problems.",
        "I'm reading a book on anti-gravity. It's impossible to put down!"
    ]

    facts = [
        "Sloths can hold their breath longer than dolphins.",
        "Octopuses have three hearts and blue blood.",
        "Bananas are berries, but strawberries aren’t."
    ]

    advice_list = [
        "Stay positive and keep moving forward!",
        "Take regular breaks while studying or working.",
        "Keep a gratitude journal—it really helps with mental clarity."
    ]

    songs = [
        "'Blinding Lights' by The Weeknd",
        "'Levitating' by Dua Lipa",
        "'Perfect' by Ed Sheeran",
        "'Shape of You' by Ed Sheeran"
    ]

    movies = [
        "Inception (2010) - Sci-Fi",
        "The Shawshank Redemption (1994) - Drama",
        "Interstellar (2014) - Sci-Fi",
        "Inside Out (2015) - Animation"
    ]

    fallback_responses = [
        "I'm not sure I understand that, but I'd love to learn more!",
        "Hmm... could you say that another way?",
        "That’s something I haven’t learned yet, but I’m here to chat!",
        "I'm not sure about that, but I'm listening!",
        "I don’t quite get that—want to rephrase it?"
    ]

    while True:
        user_input = input("You: ").lower().strip()

        if user_input in ["exit", "bye", "goodbye", "quit"]:
            name = memory['name'] or 'friend'
            print(f"Chatbot: Goodbye {name}! Take care and talk soon 💛")
            break

        if "my name is" in user_input:
            name_match = re.search(r"my name is (\w+)", user_input)
            if name_match:
                memory['name'] = name_match.group(1).capitalize()
                print(f"Chatbot: Great to meet you, {memory['name']}! 😊")
            continue

        if "i feel" in user_input:
            mood_match = re.search(r"i feel (\w+)", user_input)
            if mood_match:
                memory['mood'] = mood_match.group(1)
                print(f"Chatbot: Got it — you're feeling {memory['mood']}. Want to talk about it?")
            continue

        if re.search(r"\b(hi|hello|hey|yo|sup)\b", user_input):
            greeting = f"Hey {memory['name']}!" if memory['name'] else "Hey there!"
            print(f"Chatbot: {greeting} How can I brighten your day today?")
            continue

        if "how are you" in user_input:
            print("Chatbot: I’m all good! What about you? 😊")
            continue

        if re.search(r"\b(thanks|thank you|thx|ty|ok thanks|okay thanks|oh thanks|ohh thanks|appreciate it|thank u)\b", user_input):
            print("Chatbot: You're very welcome! 💛")
            continue

        if re.search(r"\b(nice|cool|great|awesome|sweet|amazing|lovely|beautiful|wonderful)\b", user_input):
            print("Chatbot: Glad you think so! 😄")
            continue

        if re.search(r"\b(yes|yeah|yup|sure|of course|yess|ya|ok|okay)\b", user_input):
            print("Chatbot: Awesome! Let’s go on ✨")
            continue

        if re.search(r"\b(no|nope|nah|not really|never mind|don’t)\b", user_input):
            print("Chatbot: No worries, we can switch it up! 😊")
            continue

        if "weather" in user_input:
            print("Chatbot:", get_weather())
            continue

        if re.search(r"\b(date|day|today)\b", user_input):
            print("Chatbot: Today is", datetime.today().strftime("%A, %B %d, %Y"))
            continue

        if "time" in user_input:
            print("Chatbot: It’s", datetime.now().strftime("%I:%M %p"))
            continue

        if re.search(r"\b(joke|funny|laugh)\b", user_input):
            print("Chatbot:", random.choice(jokes))
            continue

        if re.search(r"\b(fact|did you know|interesting)\b", user_input):
            print("Chatbot:", random.choice(facts))
            continue

        if re.search(r"\b(advice|tip|suggestion|recommend)\b", user_input):
            print("Chatbot:", random.choice(advice_list))
            continue

        if re.search(r"\b(song|music|listen|track)\b", user_input):
            print("Chatbot: How about listening to", random.choice(songs))
            continue

        if re.search(r"\b(movie|film|watch|cinema)\b", user_input):
            print("Chatbot: You might like:", random.choice(movies))
            continue

        if re.search(r"\d+[\+\-\*/]\d+", user_input):
            print("Chatbot:", get_math_answer(user_input))
            continue

        print("Chatbot:", random.choice(fallback_responses))

chatbot()
# Out:
# Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.
# You: hiie
# Chatbot: I'm not sure I understand that, but I'd love to learn more!
# You: hey there
# Chatbot: Hey there! How can I brighten your day today?
# You: im feeling sad
# Chatbot: I don’t quite get that—want to rephrase it?
# You: feeling sad
# Chatbot: I don’t quite get that—want to rephrase it?
# You: sad
# Chatbot: I'm not sure I understand that, but I'd love to learn more!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5d5e4f16cd8c> in <cell line: 0>()
#     146         print("Chatbot:", random.choice(fallback_responses))
#     147
# --> 148 chatbot()
#
# <ipython-input-1-5d5e4f16cd8c> in chatbot()
#      62
#      63     while True:
# ---> 64         user_input = input("You: ").lower().strip()
#      65
# ...

# %%
import random
import re
from datetime import datetime

memory = {
    "name": None,
    "mood": None
}

def get_weather():
    return "I can't fetch real-time weather yet, but I hope it's nice where you are! ☀️"

def get_math_answer(expression):
    try:
        result = eval(expression)
        return f"That equals {result}"
    except:
        return "Hmm, I couldn't calculate that. Try a simpler math expression."

def chatbot():
    print("Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.")

    jokes = [
        "Why don’t scientists trust atoms? Because they make up everything!",
        "Why did the math book look sad? Because it had too many problems.",
        "I'm reading a book on anti-gravity. It's impossible to put down!"
    ]

    facts = [
        "Sloths can hold their breath longer than dolphins.",
        "Octopuses have three hearts and blue blood.",
        "Bananas are berries, but strawberries aren’t."
    ]

    advice_list = [
        "Stay positive and keep moving forward!",
        "Take regular breaks while studying or working.",
        "Keep a gratitude journal—it really helps with mental clarity."
    ]

    songs = [
        "'Blinding Lights' by The Weeknd",
        "'Levitating' by Dua Lipa",
        "'Perfect' by Ed Sheeran",
        "'Shape of You' by Ed Sheeran"
    ]

    movies = [
        "Inception (2010) - Sci-Fi",
        "The Shawshank Redemption (1994) - Drama",
        "Interstellar (2014) - Sci-Fi",
        "Inside Out (2015) - Animation"
    ]

    fallback_responses = [
        "I'm not sure about that. Could you tell me more?",
        "Hmm... that's interesting. Want to explain it a bit?",
        "I'm still learning! Can you ask me differently?",
        "I'm not certain, but I'm curious!",
        "Sorry, that went over my circuits."
    ]

    while True:
        user_input = input("You: ").lower().strip()

        if user_input in ["exit", "bye", "goodbye", "quit"]:
            name = memory['name'] or 'friend'
            print(f"Chatbot: Goodbye {name}! Take care and talk soon 💛")
            break

        if "my name is" in user_input:
            name_match = re.search(r"my name is (\w+)", user_input)
            if name_match:
                memory['name'] = name_match.group(1).capitalize()
                print(f"Chatbot: Great to meet you, {memory['name']}! 😊")
            continue

        if "i feel" in user_input:
            mood_match = re.search(r"i feel (\w+)", user_input)
            if mood_match:
                memory['mood'] = mood_match.group(1)
                print(f"Chatbot: Got it — you're feeling {memory['mood']}. Want to talk about it?")
            continue

        if re.search(r"\b(hi|hello|hey|yo|sup)\b", user_input):
            greeting = f"Hey {memory['name']}!" if memory['name'] else "Hey there!"
            print(f"Chatbot: {greeting} How can I brighten your day today?")
            continue

        if "how are you" in user_input:
            print("Chatbot: I’m all good! What about you? 😊")
            continue

        if re.search(r"\b(thanks|thank you|thx|ty|ok thanks|okay thanks|oh thanks|ohh thanks|appreciate it|thank u|tnx)\b", user_input):
            print("Chatbot: You're very welcome! 💛")
            continue

        if re.search(r"\b(nice|cool|great|awesome|sweet|amazing|lovely|beautiful|wonderful)\b", user_input):
            print("Chatbot: Glad you think so! 😄")
            continue

        if re.search(r"\b(yes|yeah|yup|sure|of course|yess|ya|ok|okay|alright|definitely|certainly|absolutely)\b", user_input):
            print("Chatbot: Awesome! Let’s go on ✨")
            continue

        if re.search(r"\b(no|nope|nah|not really|never mind|don’t|don\\'t think so|not sure)\b", user_input):
            print("Chatbot: No worries, we can switch it up! 😊")
            continue

        if re.search(r"\b(sad|unhappy|depressed|gloomy|down|blue)\b", user_input):
            print("Chatbot: I'm here for you. Want a joke or some advice to lift your mood? 💙")
            continue

        if re.search(r"\b(happy|joyful|cheerful|glad|excited|content|delighted)\b", user_input):
            print("Chatbot: That's awesome to hear! Keep shining! 🌟")
            continue

        if re.search(r"\b(moody|confused|meh|not sure|mixed|okayish)\b", user_input):
            print("Chatbot: Sounds like a mix of feelings. Want to chat about it?")
            continue

        if "weather" in user_input:
            print("Chatbot:", get_weather())
            continue

        if re.search(r"\b(date|day|today)\b", user_input):
            print("Chatbot: Today is", datetime.today().strftime("%A, %B %d, %Y"))
            continue

        if "time" in user_input:
            print("Chatbot: It’s", datetime.now().strftime("%I:%M %p"))
            continue

        if re.search(r"\b(joke|funny|laugh)\b", user_input):
            print("Chatbot:", random.choice(jokes))
            continue

        if re.search(r"\b(fact|did you know|interesting)\b", user_input):
            print("Chatbot:", random.choice(facts))
            continue

        if re.search(r"\b(advice|tip|suggestion|recommend)\b", user_input):
            print("Chatbot:", random.choice(advice_list))
            continue

        if re.search(r"\b(song|music|listen|track)\b", user_input):
            print("Chatbot: How about listening to", random.choice(songs))
            continue

        if re.search(r"\b(movie|film|watch|cinema)\b", user_input):
            print("Chatbot: You might like:", random.choice(movies))
            continue

        if re.search(r"\d+[\+\-\*/]\d+", user_input):
            print("Chatbot:", get_math_answer(user_input))
            continue

        print("Chatbot:", random.choice(fallback_responses))

chatbot()
# Out:
# Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.
# You: hii
# Chatbot: I'm not certain, but I'm curious!
# You: hey there bot
# Chatbot: Hey there! How can I brighten your day today?
# You: how are you
# Chatbot: I’m all good! What about you? 😊
# You: im good too
# Chatbot: I'm not sure about that. Could you tell me more?
# You: tell me about ypurslf
# Chatbot: I'm not certain, but I'm curious!
# You: im felling bad
# Chatbot: I'm not certain, but I'm curious!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-04e75e8c475f> in <cell line: 0>()
#     158         print("Chatbot:", random.choice(fallback_responses))
#     159
# --> 160 chatbot()
#
# <ipython-input-2-04e75e8c475f> in chatbot()
#      62
#      63     while True:
# ---> 64         user_input = input("You: ").lower().strip()
#      65
# ...

# %%
import random
import re
from datetime import datetime

memory = {
    "name": None,
    "mood": None
}

def get_weather():
    return "I can't fetch real-time weather yet, but I hope it's nice where you are! ☀️"

def get_math_answer(expression):
    try:
        result = eval(expression)
        return f"That equals {result}"
    except:
        return "Hmm, I couldn't calculate that. Try a simpler math expression."

def chatbot():
    print("Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.")

    jokes = [
        "Why don’t scientists trust atoms? Because they make up everything!",
        "Why did the math book look sad? Because it had too many problems.",
        "I'm reading a book on anti-gravity. It's impossible to put down!"
    ]

    facts = [
        "Sloths can hold their breath longer than dolphins.",
        "Octopuses have three hearts and blue blood.",
        "Bananas are berries, but strawberries aren’t."
    ]

    advice_list = [
        "Stay positive and keep moving forward!",
        "Take regular breaks while studying or working.",
        "Keep a gratitude journal—it really helps with mental clarity."
    ]

    songs = [
        "'Blinding Lights' by The Weeknd",
        "'Levitating' by Dua Lipa",
        "'Perfect' by Ed Sheeran",
        "'Shape of You' by Ed Sheeran"
    ]

    movies = [
        "Inception (2010) - Sci-Fi",
        "The Shawshank Redemption (1994) - Drama",
        "Interstellar (2014) - Sci-Fi",
        "Inside Out (2015) - Animation"
    ]

    fallback_responses = [
        "I'm not sure about that. Could you tell me more?",
        "Hmm... that's interesting. Want to explain it a bit?",
        "I'm still learning! Can you ask me differently?",
        "I'm not certain, but I'm curious!",
        "That’s a new one for me—let’s figure it out together!"
    ]

    while True:
        user_input = input("You: ").lower().strip()

        if user_input in ["exit", "bye", "goodbye", "quit"]:
            name = memory['name'] or 'friend'
            print(f"Chatbot: Goodbye {name}! Take care and talk soon 💛")
            break

        if "my name is" in user_input:
            name_match = re.search(r"my name is (\w+)", user_input)
            if name_match:
                memory['name'] = name_match.group(1).capitalize()
                print(f"Chatbot: Great to meet you, {memory['name']}! 😊")
            continue

        if "i feel" in user_input:
            mood_match = re.search(r"i feel (\w+)", user_input)
            if mood_match:
                memory['mood'] = mood_match.group(1)
                print(f"Chatbot: Got it — you're feeling {memory['mood']}. Want to talk about it?")
            continue

        if re.search(r"\b(hi|hello|hey|yo|sup)\b", user_input):
            greeting = f"Hey {memory['name']}!" if memory['name'] else "Hey there!"
            print(f"Chatbot: {greeting} How can I brighten your day today?")
            continue

        if "how are you" in user_input:
            print("Chatbot: I’m all good! What about you? 😊")
            continue

        if re.search(r"\b(thanks|thank you|thx|ty|ok thanks|okay thanks|oh thanks|ohh thanks|appreciate it|thank u|tnx)\b", user_input):
            print("Chatbot: You're very welcome! 💛")
            continue

        if re.search(r"\b(nice|cool|great|awesome|sweet|amazing|lovely|beautiful|wonderful|funny|interesting)\b", user_input):
            print("Chatbot: Glad you think so! 😄")
            continue

        if re.search(r"\b(yes|yeah|yup|sure|of course|yess|ya|ok|okay|alright|definitely|certainly|absolutely)\b", user_input):
            print("Chatbot: Awesome! Let’s go on ✨")
            continue

        if re.search(r"\b(no|nope|nah|not really|never mind|don’t|don't think so|not sure)\b", user_input):
            print("Chatbot: No worries, we can switch it up! 😊")
            continue

        if re.search(r"\b(sad|unhappy|depressed|gloomy|down|blue)\b", user_input):
            print("Chatbot: I'm here for you. Want a joke or some advice to lift your mood? 💙")
            continue

        if re.search(r"\b(happy|joyful|cheerful|glad|excited|content|delighted)\b", user_input):
            print("Chatbot: That's awesome to hear! Keep shining! 🌟")
            continue

        if re.search(r"\b(moody|confused|meh|not sure|mixed|okayish)\b", user_input):
            print("Chatbot: Sounds like a mix of feelings. Want to chat about it?")
            continue

        if "weather" in user_input:
            print("Chatbot:", get_weather())
            continue

        if re.search(r"\b(date|day|today)\b", user_input):
            print("Chatbot: Today is", datetime.today().strftime("%A, %B %d, %Y"))
            continue

        if "time" in user_input:
            print("Chatbot: It’s", datetime.now().strftime("%I:%M %p"))
            continue

        if re.search(r"\b(joke|funny|laugh)\b", user_input):
            print("Chatbot:", random.choice(jokes))
            continue

        if re.search(r"\b(fact|did you know|interesting)\b", user_input):
            print("Chatbot:", random.choice(facts))
            continue

        if re.search(r"\b(advice|tip|suggestion|recommend)\b", user_input):
            print("Chatbot:", random.choice(advice_list))
            continue

        if re.search(r"\b(song|music|listen|track)\b", user_input):
            print("Chatbot: How about listening to", random.choice(songs))
            continue

        if re.search(r"\b(movie|film|watch|cinema)\b", user_input):
            print("Chatbot: You might like:", random.choice(movies))
            continue

        if re.search(r"\d+[\+\-\*/]\d+", user_input):
            print("Chatbot:", get_math_answer(user_input))
            continue

        print("Chatbot:", random.choice(fallback_responses))

chatbot()
# Out:
# Chatbot: Hey there! I'm SmartBot 🤖. Ready to chat, help, or make you smile 😊. Type 'bye' to exit.
# You: hii
# Chatbot: I'm not sure about that. Could you tell me more?
# You: how are you
# Chatbot: I’m all good! What about you? 😊
# You: hey
# Chatbot: Hey there! How can I brighten your day today?
# You: im feeling sad
# Chatbot: I'm here for you. Want a joke or some advice to lift your mood? 💙
# You: yes please
# Chatbot: Awesome! Let’s go on ✨
# You: tell me a joke
# Chatbot: Why did the math book look sad? Because it had too many problems.
# You: haha
# Chatbot: I'm still learning! Can you ask me differently?
# You: advice me a song'
# Chatbot: Stay positive and keep moving forward!
# You: song
# Chatbot: How about listening to 'Perfect' by Ed Sheeran
# You: thanks
# Chatbot: You're very welcome! 💛
